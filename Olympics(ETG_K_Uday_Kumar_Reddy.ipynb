# %%
import pandas as pd

# %%
df = pd.read_csv("summer.csv")

# %%
df
# Out:
#        Year    City      Sport  ... Gender                       Event   Medal
# 0      1896  Athens   Aquatics  ...    Men              100M Freestyle    Gold
# 1      1896  Athens   Aquatics  ...    Men              100M Freestyle  Silver
# 2      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Bronze
# 3      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors    Gold
# 4      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Silver
# ...     ...     ...        ...  ...    ...                         ...     ...
# 31160  2012  London  Wrestling  ...    Men                    Wg 84 KG  Bronze
# 31161  2012  London  Wrestling  ...    Men                    Wg 96 KG    Gold
# 31162  2012  London  Wrestling  ...    Men                    Wg 96 KG  Silver
# 31163  2012  London  Wrestling  ...    Men                    Wg 96 KG  Bronze
# 31164  2012  London  Wrestling  ...    Men                    Wg 96 KG  Bronze
#
# ...

# %%
df.isnull().sum()
# Out:
# Year          0
# City          0
# Sport         0
# Discipline    0
# Athlete       0
# Country       4
# Gender        0
# Event         0
# Medal         0
# dtype: int64

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of        Year    City      Sport  ... Gender                       Event   Medal
# 0      1896  Athens   Aquatics  ...    Men              100M Freestyle    Gold
# 1      1896  Athens   Aquatics  ...    Men              100M Freestyle  Silver
# 2      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Bronze
# 3      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors    Gold
# 4      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Silver
# ...     ...     ...        ...  ...    ...                         ...     ...
# 31160  2012  London  Wrestling  ...    Men                    Wg 84 KG  Bronze
# 31161  2012  London  Wrestling  ...    Men                    Wg 96 KG    Gold
# 31162  2012  London  Wrestling  ...    Men                    Wg 96 KG  Silver
# 31163  2012  London  Wrestling  ...    Men                    Wg 96 KG  Bronze
# ...

# %% [markdown]
# ##  1. In how many cities summer Olypics is held so far?

# %%
df['City'].unique()
# Out:
# array(['Athens', 'Paris', 'St Louis', 'London', 'Stockholm', 'Antwerp',
#        'Amsterdam', 'Los Angeles', 'Berlin', 'Helsinki',
#        'Melbourne / Stockholm', 'Rome', 'Tokyo', 'Mexico', 'Munich',
#        'Montreal', 'Moscow', 'Seoul', 'Barcelona', 'Atlanta', 'Sydney',
#        'Beijing'], dtype=object)

# %%
Number_of_Cities = len(df['City'].unique())
print("Number of cities in summer olypics: ", Number_of_Cities)
# Out:
# Number of cities in summer olypics:  22

# %% [markdown]
# ##  2. Which sport is having most number of Medals so far?

# %%
df["Medal"].unique()
# Out:
# array(['Gold', 'Silver', 'Bronze'], dtype=object)

# %%
df.groupby('Sport').count()['Medal'].sort_values(ascending = False).head().plot.bar(figsize = (10,5))

# %% [markdown]
# ## 3. Which Athlete is having most number of Medals so far?

# %%
df.groupby('Athlete').count()['Medal'].sort_values(ascending = False).head().plot.bar(figsize = (15,5))

# %% [markdown]
# ## 4.Which Event is most popular in terms of number of players??

# %%
df.groupby('Discipline').count()['Gender'].sort_values(ascending = False).head().plot.bar(figsize = (15,5))

# %% [markdown]
# ## 5.Which Sport is having most number of Gold Medals so far??(Top 5)

# %%
data = []

for Gold in df['Sport'].unique():
  data.append([Gold , len(df[df['Sport']  == Gold])])

pd.DataFrame(data,columns = ['Sport','Gold']).sort_values(by='Gold', ascending=False).head().plot(x = 'Sport', y = 'Gold', kind = 'bar', figsize = (5,5))

# %%
data
# Out:
# [['Aquatics', 4170],
#  ['Athletics', 3638],
#  ['Cycling', 1105],
#  ['Fencing', 1613],
#  ['Gymnastics', 2307],
#  ['Shooting', 1150],
#  ['Tennis', 296],
#  ['Weightlifting', 593],
#  ['Wrestling', 1212],
#  ['Archery', 329],
#  ['Basque Pelota', 4],
#  ['Cricket', 24],
#  ['Croquet', 8],
#  ['Equestrian', 939],
#  ['Football', 1497],
#  ['Golf', 30],
#  ['Polo', 66],
#  ['Rowing', 2667],
#  ['Rugby', 192],
#  ['Sailing', 1109],
#  ['Tug of War', 94],
#  ['Boxing', 894],
#  ['Lacrosse', 59],
#  ['Roque', 3],
#  ['Hockey', 1422],
#  ['Jeu de paume', 3],
#  ['Rackets', 10],
#  ['Skating', 27],
#  ['Water Motorsports', 5],
#  ['Modern Pentathlon', 180],
#  ['Ice Hockey', 27],
#  ['Basketball', 1012],
#  ['Canoe / Kayak', 1002],
#  ['Handball', 973],
#  ['Judo', 491],
#  ['Volleyball', 994],
#  ['Table Tennis', 144],
#  ['Badminton', 144],
#  ['Baseball', 335],
#  ['Softball', 180],
#  ['Taekwondo', 112],
#  ['Triathlon', 24],
#  ['Canoe', 81]]

# %% [markdown]
# ### 6.Which Players has won most number of Gold Medals of Medals??

# %%
data = []

for Gold in df['Athlete'].unique():
  data.append([Gold , len(df[df['Athlete']  == Gold])])

# %%
data
# Out:
# [['HAJOS, Alfred', 2],
#  ['HERSCHMANN, Otto', 2],
#  ['DRIVAS, Dimitrios', 1],
#  ['MALOKINIS, Ioannis', 1],
#  ['CHASAPIS, Spiridon', 1],
#  ['CHOROPHAS, Efstathios', 2],
#  ['ANDREOU, Joannis', 1],
#  ['NEUMANN, Paul', 1],
#  ['PEPANOS, Antonios', 1],
#  ['LANE, Francis', 1],
#  ['SZOKOLYI, Alajos', 1],
#  ['BURKE, Thomas', 2],
#  ['HOFMANN, Fritz', 4],
#  ['CURTIS, Thomas', 1],
#  ['GOULDING, Grantley', 1],
#  ['LERMUSIAUX, Albin', 1],
#  ['FLACK, Edwin', 3],
#  ['BLAKE, Arthur', 1],
#  ['GMELIN, Charles', 1],
#  ['JAMISON, Herbert', 1],
#  ['GOLEMIS, Dimitrios', 1],
#  ['DANI, Nandor', 1],
#  ['VERSIS, Sotirios', 2],
#  ['GARRETT, Robert', 6],
#  ['PARASKEVOPOULOS, Panagiotis', 1],
#  ['CLARK, Ellery', 2],
#  ['CONNOLLY, James', 5],
#  ['KELLNER, Gyula', 1],
#  ['LOUIS, Spyridon', 1],
#  ['VASILAKOS, Kharilaos', 1],
#  ['DAMASKOS, Evangelos', 1],
#  ['THEODOROPOULOS, Ioannis', 1],
#  ['HOYT, William Welles', 1],
#  ['TYLER, Albert', 1],
#  ['PAPASIDERIS, Georgios', 1],
# ...

# %%
data = []

for Gold in df['Athlete'].unique():
  data.append([Gold , len(df[df['Athlete']  == Gold])])

pd.DataFrame(data,columns = ['Athlete','Gold']).sort_values(by='Gold', ascending=False).head().plot(x = 'Athlete', y = 'Gold', kind = 'bar', figsize = (5,5))
